# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_user = pd.read_csv("/content/drive/MyDrive/Data Science Project/Social Graph PPKM/node.csv")
df_user
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 user_screen_name  \
# 0              2             2               2     nieke_aereta
# 1              3             3               3       ferizandra
# 2              5             5               5       EmilDardak
# 3              7             7               7   PutraErlangga_
# 4              8             8               8        BennyKeef
# ...          ...           ...             ...              ...
# 4466       16676         18763           18763      elProgresif
# 4467       16689         18776           18776       Al_Aslan20
# 4468       16693         18780           18780    van1llaLattee
# 4469       16695         18782           18782    semangkasegar
# 4470       16697         18784           18784     johanstraus3
#
#                        user_name gender  stance
# 0           Olivia Nieke Yuliane      w  kontra
# 1                     ferizandra      w     pro
# 2                  Emil E Dardak      m  kontra
# ...

# %% [markdown]
# ## PPKM Pro

# %%
df_user_pro = df_user.loc[df_user["stance"]=="pro"]
df_user_pro
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 user_screen_name  \
# 1              3             3               3       ferizandra
# 3              7             7               7   PutraErlangga_
# 4              8             8               8        BennyKeef
# 5             10            10              10      newsplatter
# 6             13            14              14      AlbertSolo2
# ...          ...           ...             ...              ...
# 4462       16652         18738           18738      Davendraa__
# 4464       16667         18753           18753   blubuk__blubuk
# 4465       16674         18761           18761           Lamz48
# 4467       16689         18776           18776       Al_Aslan20
# 4468       16693         18780           18780    van1llaLattee
#
#                                               user_name gender stance
# 1                                            ferizandra      w    pro
# ...

# %%
jml_user_pro_m = df_user_pro.gender.value_counts().m
jml_user_pro_w = df_user_pro.gender.value_counts().w
data = [jml_user_pro_m, jml_user_pro_w]
label = ["Man","Woman"]

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = label)
 
# show plot
plt.show()

# %% [markdown]
# ## PPKM Kontra

# %%
df_user_kontra = df_user.loc[df_user["stance"]=="kontra"]
df_user_kontra
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 user_screen_name  \
# 0              2             2               2     nieke_aereta
# 2              5             5               5       EmilDardak
# 8             16            17              17           zimi95
# 10            20            21              21        Rizmaya__
# 13            26            27              27          erna_st
# ...          ...           ...             ...              ...
# 4461       16649         18735           18735        Pinkambem
# 4463       16655         18741           18741   LiberalDialect
# 4466       16676         18763           18763      elProgresif
# 4469       16695         18782           18782    semangkasegar
# 4470       16697         18784           18784     johanstraus3
#
#                        user_name gender  stance
# 0           Olivia Nieke Yuliane      w  kontra
# 2                  Emil E Dardak      m  kontra
# 8                         Tɑmɑrɑ      w  kontra
# ...

# %%
jml_user_kontra_m = df_user_kontra.gender.value_counts().m
jml_user_kontra_w = df_user_kontra.gender.value_counts().w
data = [jml_user_kontra_m, jml_user_kontra_w]
label = ["Man","Woman"]

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = label)
 
# show plot
plt.show()

# %% [markdown]
# ## All Gender Analysis

# %%
import numpy as np
outer = [df_user.gender.value_counts().m,df_user.gender.value_counts().w]
outer_label = ["Man","Woman"]

inner = np.array([[jml_user_kontra_m, jml_user_pro_m], [jml_user_kontra_w, jml_user_pro_w]])
inner_label = ["Kontra","Pro","Kontra","Pro"]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(24,12))
size = 0.3

ax.pie(outer, radius=1,
       labels=outer_label,
       autopct='%1.1f%%',
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(inner.flatten(), radius=1-size, 
       labels = inner_label,
       wedgeprops=dict(width=size, edgecolor='w'))

plt.show()
